# %%
import pandas as pd
#Read the provided csv file 'data.csv'
df = pd.read_csv('/data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#Show the basic statistical description about the data
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   169.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   262.385991
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   253.300000
# 50%     60.000000  105.000000  131.000000   321.000000
# 75%     60.000000  111.000000  141.000000   384.000000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#check if the data has null values
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
#Replace the null values with mean
df.fillna(df.mean(), inplace=True)
print(df)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
# Select two columns and aggregate the data
df_agg = df[['Duration', 'Pulse']].agg(['min', 'max', 'count', 'mean'])
print(df_agg)
# Out:
#          Duration       Pulse
# min     15.000000   80.000000
# max    300.000000  159.000000
# count  169.000000  169.000000
# mean    63.846154  107.461538

# %%
# Filter the dataframe to select the rows with calories values between 500 and 1000
filtered_df = df[(df['Calories'] >= 500) & (df['Calories'] <= 1000)]
print(filtered_df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
# Filter the dataframe to select the rows with calories values > 500 and pulse < 100
filtered_df = df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
print(filtered_df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df.drop(columns=['Maxpulse'], inplace=False)
print(df_modified)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df.drop(columns=['Maxpulse'], inplace=True)
print(df)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df['Calories'] = df['Calories'].astype(int)
print(df.dtypes)
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter', x='Duration', y='Calories', alpha=0.5, color='blue')
plt.title('Scatter Plot of Duration vs Calories')
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.show()

# %%
import pandas as pd
df2 = pd.read_csv('/Salary_Data (2) (1).csv')
print(df2)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df, test_size=1/3, random_state=42)
print("Training setshape:", X_train.shape)
print("Test setshape:", X_test.shape)
# Out:
# Training setshape: (112, 3)
# Test setshape: (57, 3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
X = df2['YearsExperience'].values.reshape(-1, 1)
y = df2['Salary']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# Out:
# [115814.30756236  71511.92534771 102617.85328566  75282.34085534
#   55487.65944028  60200.67882482 122412.53470072 107330.8726702
#   63028.49045554  35692.97802523]
# Mean Absolute Error: 4956.5232614449005
# Mean Squared Error: 35301898.887134895

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['Duration']]
y = df['Calories']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.plot(X_train, y_pred_train, color='red', label='Model fit')
plt.title('Training Data')
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(X_test, y_test, color='green', label='Testing data')
plt.plot(X_test, y_pred_test, color='red', linestyle='--', label='Model predictions')
plt.title('Testing Data')
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.legend()

plt.tight_layout()
plt.show()
